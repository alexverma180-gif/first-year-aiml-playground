# %% [markdown]
# # Data Cleaning Basics
# Simple EDA and cleaning using the Iris dataset contained in `app/data/iris.csv`.

# %%
import pandas as pd
df = pd.read_csv('../app/data/iris.csv')
df.head()

# %%
df.info()

# %%
df.describe(numeric_only=True)

# %%
# Handle missing values if any
df = df.dropna()
df.isna().sum()
